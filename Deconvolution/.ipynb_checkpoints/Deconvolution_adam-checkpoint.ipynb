# %%
# %matplotlib inline

import sys
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
import os

# %%
# Import dff
import h5py
filename = 'C:/Users/Hippolyte Moulle/Documents/LJP_datasets/2018-05-24Run08.h5'
with h5py.File(filename, 'r') as f:
    dff = f['Data']['Brain']['Analysis']['DFF'].value
    dff = np.array(dff)
    time = f['Data']['Brain']['Times'].value
    time = time[1] - time[0]
n = dff.shape[0]
print('Number of time points is ', n)
print('Time increment is ', time)


# Get first signal
signal = dff[:, 0]
#signal = np.expand_dims(signal, 1)
print('Signal shape is ', signal.shape)
# Out:
# Number of time points is  3000
# Time increment is  [0.4]
# Signal shape is  (3000,)

# %%
# Build exponential kernal
expdecay = 10
exptime = np.arange(6*expdecay/time)
expkern = np.exp(-exptime/expdecay)
elen = expkern.shape[0]
plt.plot(time*np.arange(elen), expkern)
print('Size of exponential is ', expkern.shape)
# Out:
# Size of exponential is  (150,)

# %%
# Build exponential matrix
expmat = np.zeros((n+2*(elen-1), n+elen-1))
for kern in range(n+elen-1):
    expmat[kern:kern+elen, kern] = expkern
expmat = expmat[elen-1:n+elen-1]
plt.imshow(expmat[-50:, -50:])

# %%
# Define dataset for keras model
X = expmat
y = signal
print(X.shape, y.shape)
# Out:
# (3000, 3149) (3000,)

# %%
# Build keras model
from keras.layers import Dense
from keras.models import Sequential
from keras.constraints import MinMaxNorm, NonNeg
model = Sequential()
model.add(Dense(1, input_dim=X.shape[1], use_bias=False, kernel_constraint=NonNeg()))
#model.add(Dense(1, input_dim=X.shape[1], use_bias=False, kernel_constraint=MinMaxNorm(min_value=0.0, max_value=1.0, rate=1.0, axis=0)))
model.add(Dense(1, kernel_constraint=NonNeg(), bias_constraint=NonNeg()))
model.summary()
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 1)                 3149
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 3,151
# Trainable params: 3,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 3000/3000 [==============================] - 1s 183us/step - loss: 0.0032 - mean_absolute_error: 0.0383
# Epoch 2/50
# 3000/3000 [==============================] - 0s 39us/step - loss: 0.0014 - mean_absolute_error: 0.0256
# Epoch 3/50
# 3000/3000 [==============================] - 0s 37us/step - loss: 8.5214e-04 - mean_absolute_error: 0.0207
# Epoch 4/50
# 3000/3000 [==============================] - 0s 37us/step - loss: 6.5283e-04 - mean_absolute_error: 0.0186
# Epoch 5/50
# 3000/3000 [==============================] - 0s 40us/step - loss: 5.6028e-04 - mean_absolute_error: 0.0175
# Epoch 6/50
# 3000/3000 [==============================] - 0s 39us/step - loss: 4.9832e-04 - mean_absolute_error: 0.0167
# Epoch 7/50
# 3000/3000 [==============================] - 0s 40us/step - loss: 4.5612e-04 - mean_absolute_error: 0.0162
# Epoch 8/50
# 3000/3000 [==============================] - 0s 47us/step - loss: 4.3575e-04 - mean_absolute_error: 0.0159
# Epoch 9/50
# 3000/3000 [==============================] - 0s 38us/step - loss: 4.1228e-04 - mean_absolute_error: 0.0155
# Epoch 10/50
# 3000/3000 [==============================] - 0s 39us/step - loss: 3.9633e-04 - mean_absolute_error: 0.0153
# Epoch 11/50
# 3000/3000 [==============================] - 0s 40us/step - loss: 3.8397e-04 - mean_absolute_error: 0.0150
# Epoch 12/50
# 3000/3000 [==============================] - 0s 33us/step - loss: 3.7507e-04 - mean_absolute_error: 0.0149
# Epoch 13/50
# 3000/3000 [==============================] - 0s 30us/step - loss: 3.6802e-04 - mean_absolute_error: 0.0149
# Epoch 14/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.5715e-04 - mean_absolute_error: 0.0146
# Epoch 15/50
# 3000/3000 [==============================] - 0s 30us/step - loss: 3.5590e-04 - mean_absolute_error: 0.0147
# Epoch 16/50
# 3000/3000 [==============================] - 0s 29us/step - loss: 3.4459e-04 - mean_absolute_error: 0.0144
# Epoch 17/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.3933e-04 - mean_absolute_error: 0.0143
# Epoch 18/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.3966e-04 - mean_absolute_error: 0.0142
# Epoch 19/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.3612e-04 - mean_absolute_error: 0.0142
# Epoch 20/50
# 3000/3000 [==============================] - 0s 33us/step - loss: 3.3668e-04 - mean_absolute_error: 0.0142
# Epoch 21/50
# 3000/3000 [==============================] - 0s 33us/step - loss: 3.2775e-04 - mean_absolute_error: 0.0140
# Epoch 22/50
# 3000/3000 [==============================] - 0s 30us/step - loss: 3.2720e-04 - mean_absolute_error: 0.0140
# Epoch 23/50
# 3000/3000 [==============================] - 0s 33us/step - loss: 3.2824e-04 - mean_absolute_error: 0.0140
# Epoch 24/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.2099e-04 - mean_absolute_error: 0.0138
# Epoch 25/50
# 3000/3000 [==============================] - 0s 30us/step - loss: 3.1651e-04 - mean_absolute_error: 0.0137
# Epoch 26/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.2409e-04 - mean_absolute_error: 0.0138
# Epoch 27/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.2190e-04 - mean_absolute_error: 0.0138
# Epoch 28/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.1678e-04 - mean_absolute_error: 0.0137
# Epoch 29/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.1474e-04 - mean_absolute_error: 0.0136
# Epoch 30/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.1315e-04 - mean_absolute_error: 0.0136
# Epoch 31/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.1446e-04 - mean_absolute_error: 0.0137
# Epoch 32/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.1235e-04 - mean_absolute_error: 0.0135
# Epoch 33/50
# 3000/3000 [==============================] - 0s 30us/step - loss: 3.1108e-04 - mean_absolute_error: 0.0135
# Epoch 34/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.1155e-04 - mean_absolute_error: 0.0135
# Epoch 35/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.1197e-04 - mean_absolute_error: 0.0135
# Epoch 36/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.0730e-04 - mean_absolute_error: 0.0133
# Epoch 37/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.0738e-04 - mean_absolute_error: 0.0135
# Epoch 38/50
# 3000/3000 [==============================] - 0s 30us/step - loss: 3.0810e-04 - mean_absolute_error: 0.0134
# Epoch 39/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.0730e-04 - mean_absolute_error: 0.0134
# Epoch 40/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.0848e-04 - mean_absolute_error: 0.0134
# Epoch 41/50
# 3000/3000 [==============================] - 0s 30us/step - loss: 3.0674e-04 - mean_absolute_error: 0.0133
# Epoch 42/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.0481e-04 - mean_absolute_error: 0.0133
# Epoch 43/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.0263e-04 - mean_absolute_error: 0.0132
# Epoch 44/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 3.0561e-04 - mean_absolute_error: 0.0133
# Epoch 45/50
# 3000/3000 [==============================] - 0s 36us/step - loss: 3.0237e-04 - mean_absolute_error: 0.0133
# Epoch 46/50
# 3000/3000 [==============================] - 0s 34us/step - loss: 3.0063e-04 - mean_absolute_error: 0.0132
# Epoch 47/50
# 3000/3000 [==============================] - 0s 34us/step - loss: 3.0451e-04 - mean_absolute_error: 0.0133
# Epoch 48/50
# 3000/3000 [==============================] - 0s 33us/step - loss: 3.0159e-04 - mean_absolute_error: 0.0132
# Epoch 49/50
# 3000/3000 [==============================] - 0s 32us/step - loss: 3.0504e-04 - mean_absolute_error: 0.0133
# Epoch 50/50
# 3000/3000 [==============================] - 0s 31us/step - loss: 2.9970e-04 - mean_absolute_error: 0.0132

# %%
temp = model.get_weights()
print(temp)
print(temp[0].shape, temp[1].shape, temp[2].shape)
toplot = 1000
plt.plot(temp[0][:toplot])
# Out:
# [array([[ 0.02865185],
#        [ 0.00013907],
#        [ 0.00014347],
#        ...,
#        [ 0.00045156],
#        [ 0.00046446],
#        [-0.        ]], dtype=float32), array([[0.32566756]], dtype=float32), array([-0.], dtype=float32)]
# (3149, 1) (1, 1) (1,)

# %%
plt.plot(y[:toplot])
plt.plot(temp[1]*np.matmul(X, temp[0])[:toplot]+temp[2])
